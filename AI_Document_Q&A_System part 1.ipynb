# %%
import sys
# !{sys.executable} -m pip install -q cassio datasets langchain langchain-core langchain-community langchain-openai openai tiktoken pypdf2 --upgrade

# %% [markdown]
# Import the packages you'll need:

# %%
from langchain_community.vectorstores import Cassandra
from langchain_openai import OpenAI
from langchain_openai import OpenAIEmbeddings
from langchain.chains.retrieval import RetrievalQA

from datasets import load_dataset

import cassio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3272349399.py in <cell line: 0>()
#       2 from langchain_openai import OpenAI
#       3 from langchain_openai import OpenAIEmbeddings
# ----> 4 from langchain.chains.retrieval import RetrievalQA
#       5
#       6 from datasets import load_dataset
#
# ModuleNotFoundError: No module named 'langchain.chains'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
try:
    from langchain.chains.retrieval import RetrievalQA
    print("'langchain.chains.retrieval.RetrievalQA' imported successfully. The package is installed correctly.")
except ModuleNotFoundError:
    print("'langchain.chains.retrieval' is NOT installed or accessible.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# 'langchain.chains.retrieval' is NOT installed or accessible.

# %%
try:
    from langchain.chains.retrieval import RetrievalQA
    print("'langchain.chains.retrieval.RetrievalQA' imported successfully. The package is installed correctly.")
except ModuleNotFoundError:
    print("'langchain.chains.retrieval' is NOT installed or accessible.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# 'langchain.chains.retrieval' is NOT installed or accessible.

# %%
# This cell is no longer needed as pip install PyPDF2 is moved to the initial installation cell.

# %%
from PyPDF2 import PdfReader
